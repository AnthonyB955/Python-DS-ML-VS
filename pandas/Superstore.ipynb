# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_store = pd.read_excel("superstore.xls")

# %%
df_store.sample(10)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 2544    2545  US-2016-114174 2016-09-08 2016-09-14  Standard Class
# 2874    2875  US-2017-102638 2017-12-29 2017-12-31     First Class
# 6393    6394  CA-2016-129126 2016-12-14 2016-12-19  Standard Class
# 5870    5871  CA-2016-128223 2016-06-14 2016-06-14        Same Day
# 7565    7566  US-2016-166660 2016-01-30 2016-02-01    Second Class
# 4023    4024  CA-2017-130764 2017-10-27 2017-10-28     First Class
# 9695    9696  US-2016-151260 2016-12-11 2016-12-14     First Class
# 2520    2521  CA-2016-124352 2016-10-15 2016-10-21  Standard Class
# 1021    1022  CA-2015-124450 2015-04-27 2015-05-03  Standard Class
# 2283    2284  CA-2015-153108 2015-03-05 2015-03-09  Standard Class
#
#      Customer ID    Customer Name      Segment        Country           City  \
# 2544    AP-10720       Anne Pryor  Home Office  United States         Malden
# ...

# %%
df_store.drop('Row ID', axis=1, inplace=True)

# %%
df_store.sample(10)
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 614   CA-2017-138611 2017-11-14 2017-11-17    Second Class    CK-12595
# 6885  CA-2017-123036 2017-09-10 2017-09-17  Standard Class    HA-14905
# 5284  CA-2014-133424 2014-03-30 2014-04-04  Standard Class    Dl-13600
# 3144  US-2016-148110 2016-09-05 2016-09-11  Standard Class    AR-10825
# 9597  CA-2017-104619 2017-01-24 2017-01-29  Standard Class    KD-16495
# 1523  CA-2015-144806 2015-12-06 2015-12-11  Standard Class    GH-14425
# 1043  CA-2017-115651 2017-07-09 2017-07-12     First Class    NS-18640
# 4833  CA-2014-120278 2014-11-07 2014-11-12  Standard Class    MS-17365
# 5644  CA-2017-120719 2017-03-23 2017-03-26     First Class    SJ-20125
# 9592  US-2016-105452 2016-07-28 2016-08-01  Standard Class    BF-11005
#
#             Customer Name      Segment        Country         City  \
# 614          Clytie Kelty     Consumer  United States   Grove City
# ...

# %%
df_store.shape
# Out:
# (9994, 20)

# %%
df_store_subset = df_store.loc[
                               [i for i in range(5,20) ],
                               ['Customer ID','Customer Name','City','Postal Code','Sales']
                               ]

# %%
df_store_subset
# Out:
#    Customer ID       Customer Name           City  Postal Code     Sales
# 5     BH-11710     Brosina Hoffman    Los Angeles        90032    48.860
# 6     BH-11710     Brosina Hoffman    Los Angeles        90032     7.280
# 7     BH-11710     Brosina Hoffman    Los Angeles        90032   907.152
# 8     BH-11710     Brosina Hoffman    Los Angeles        90032    18.504
# 9     BH-11710     Brosina Hoffman    Los Angeles        90032   114.900
# 10    BH-11710     Brosina Hoffman    Los Angeles        90032  1706.184
# 11    BH-11710     Brosina Hoffman    Los Angeles        90032   911.424
# 12    AA-10480        Andrew Allen        Concord        28027    15.552
# 13    IM-15070        Irene Maddox        Seattle        98103   407.976
# 14    HP-14815       Harold Pawlan     Fort Worth        76106    68.810
# 15    HP-14815       Harold Pawlan     Fort Worth        76106     2.544
# 16    PK-19075           Pete Kriz        Madison        53711   665.880
# ...

# %%
df_store_sale_profit = df_store.loc[  [i for i in range(100,300)], ['Sales','Profit']    ]

# %%
df_store_sale_profit.describe()
# Out:
#              Sales       Profit
# count   200.000000   200.000000
# mean    281.996388    -1.985720
# std     734.911445   172.678412
# min       1.624000 -1359.992000
# 25%      20.317500     0.164850
# 50%      69.900000     6.804300
# 75%     238.644000    22.837000
# max    8159.952000   636.000300

# %%
boxplot = df_store_sale_profit.boxplot()

# %%
df_store['State'].nunique()
# Out:
# 49

# %%
df_store['Country'].unique()
# Out:
# array(['United States'], dtype=object)

# %%
df_store.drop('Country', axis=1, inplace=True)

# %%
df_store
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0     CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1     CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2     CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3     US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4     US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# ...              ...        ...        ...             ...         ...
# 9989  CA-2014-110422 2014-01-21 2014-01-23    Second Class    TB-21400
# 9990  CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# 9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# 9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# 9993  CA-2017-119914 2017-05-04 2017-05-09    Second Class    CC-12220
#
#          Customer Name    Segment             City       State  Postal Code  \
# ...

# %%
df_store['Segment'].unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)
